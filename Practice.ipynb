# %% [markdown]
# <a href="https://colab.research.google.com/github/Patsonu63/practice/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def right_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        print()

def inverted_right_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n, 0, -1):
        for j in range(i):
            print(alphabet[j], end=' ')
        print()

def left_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        print()

def inverted_left_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * i, end='')
        for j in range(n - i):
            print(alphabet[j], end=' ')
        print()

def pyramid(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        for j in range(i):
            print(alphabet[i - j - 1], end=' ')
        print()

def inverted_pyramid(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n, 0, -1):
        print(' ' * (n - i), end='')
        for j in range(i):
            print(alphabet[j], end=' ')
        for j in range(i - 1):
            print(alphabet[i - j - 2], end=' ')
        print()

def diamond(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        for j in range(i):
            print(alphabet[i - j - 1], end=' ')
        print()
    for i in range(n - 2, -1, -1):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        for j in range(i):
            print(alphabet[i - j - 1], end=' ')
        print()

def right_pascals_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        print()
    for i in range(n - 1):
        for j in range(n - i - 1):
            print(alphabet[j], end=' ')
        print()

def left_pascals_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            print(alphabet[j], end=' ')
        print()
    for i in range(n - 1):
        print(' ' * (i + 1), end='')
        for j in range(n - i - 1):
            print(alphabet[j], end=' ')
        print()

def sandglass(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n, 0, -1):
        print(' ' * (n - i), end='')
        for j in range(i):
            print(alphabet[j], end=' ')
        print()
    for i in range(1, n + 1):
        print(' ' * (n - i), end='')
        for j in range(i):
            print(alphabet[j], end=' ')
        print()

def reverse_right_triangle(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        for j in range(n - i):
            print(alphabet[j], end=' ')
        print()

def hollow_pyramid(n):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in range(n):
        print(' ' * (n - i - 1), end='')
        for j in range(i + 1):
            if j == 0 or j == i:
                print(alphabet[j], end=' ')
            else:
                print(' ', end=' ')
        print()

n = 5
right_triangle(n)
print()
inverted_right_triangle(n)
print()
left_triangle(n)
print()
inverted_left_triangle(n)
print()
pyramid(n)
print()
inverted_pyramid(n)
print()
diamond(n)
print()
right_pascals_triangle(n)
print()
left_pascals_triangle(n)
print()
sandglass(n)
print()
reverse_right_triangle(n)
print()
hollow_pyramid(n)
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E
#
# A B C D E
# A B C D
# A B C
# A B
# A
#
#     A
#    A B
#   A B C
#  A B C D
# A B C D E
#
# A B C D E
#  A B C D
#   A B C
#    A B
#     A
#
#     A
#    A B A
#   A B C B A
#  A B C D C B A
# A B C D E D C B A
#
# A B C D E D C B A
#  A B C D C B A
#   A B C B A
#    A B A
#     A
#
#     A
#    A B A
#   A B C B A
#  A B C D C B A
# A B C D E D C B A
#  A B C D C B A
#   A B C B A
#    A B A
#     A
#
# A
# A B
# A B C
# A B C D
# A B C D E
# A B C D
# A B C
# A B
# A
#
#     A
#    A B
#   A B C
#  A B C D
# A B C D E
#  A B C D
#   A B C
#    A B
#     A
#
# A B C D E
#  A B C D
#   A B C
#    A B
#     A
#     A
#    A B
#   A B C
#  A B C D
# A B C D E
#
# A B C D E
# A B C D
# A B C
# A B
# A
#
#     A
#    A B
#   A   C
#  A     D
# A       E

# %%
def print_gayatri_mantra():
    gayatri_mantra = """
    ॐ भूर्भुवः॒ स्वः॒
    तत्स॑वितुर्वरे॑ण्यम्।
    भ॒र्गो॑ दे॒वस्य॑ धीमहि।
    धियो॒ यो नः॑ प्रचो॒दया॑त्॥
    """

    print(gayatri_mantra)

# Calling the function to print the Gayatri Mantra
print_gayatri_mantra()
# Out:
#     ॐ भूर्भुवः॒ स्वः॒
#     तत्स॑वितुर्वरे॑ण्यम्।
#     भ॒र्गो॑ दे॒वस्य॑ धीमहि।
#     धियो॒ यो नः॑ प्रचो॒दया॑त्॥

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_spur_gear(num_teeth, pitch_circle_radius):
    fig, ax = plt.subplots()

    # Parameters for the gear
    pitch_radius = pitch_circle_radius
    tooth_angle = 2 * np.pi / num_teeth
    addendum = 0.1 * pitch_radius  # Addendum (length of teeth)
    dedendum = 0.15 * pitch_radius  # Dedendum (depth of teeth)

    # Draw gear teeth
    for i in range(num_teeth):
        theta = i * tooth_angle
        x = [pitch_radius * np.cos(theta), (pitch_radius + addendum) * np.cos(theta)]
        y = [pitch_radius * np.sin(theta), (pitch_radius + addendum) * np.sin(theta)]
        ax.plot(x, y, color='black')

    # Draw pitch circle
    pitch_circle = plt.Circle((0, 0), pitch_radius, fill=False, edgecolor='blue')
    ax.add_artist(pitch_circle)

    # Draw outer circle (just for visual reference)
    outer_circle = plt.Circle((0, 0), pitch_radius + addendum + dedendum, fill=False, linestyle='--', edgecolor='gray')
    ax.add_artist(outer_circle)

    # Set equal scaling and labels
    ax.set_aspect('equal', adjustable='box')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title(f'Spur Gear with {num_teeth} Teeth')

    plt.grid(True)
    plt.show()

# Define parameters for the gear
num_teeth = 68
pitch_circle_radius = 5  # Adjust this radius as needed for visual representation

# Draw the spur gear
draw_spur_gear(num_teeth, pitch_circle_radius)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Given data
P_hp = 125  # Power transmitted in horsepower
N = 250  # Shaft speed in rpm
D_inches = 2  # Shaft diameter in inches
tau_design = 19000  # Design stress for shear in psi
sigma_design = 37000  # Design stress for bearing in psi

# Convert shaft diameter from inches to meters
D = D_inches * 0.0254  # Convert inches to meters

# Convert power from horsepower to watts
P_watts = P_hp * 745.7  # 1 horsepower = 745.7 watts

# Calculate torque (T) in N*m
T = P_watts * 60 / (2 * np.pi * N)  # P = 2 * pi * N * T / 60

# Initialize dimensions of the key
l = 0.02  # Initial length of the key (meters)
h = 0.01  # Initial height of the key (meters)

# Function to calculate shear stress (tau) on the key
def calculate_tau(l, h):
    return T / (tau_design * l * h / 2)

# Function to calculate bearing stress (sigma) on the key
def calculate_sigma(l, h):
    return 2 * T / (D * h)

# Iterate to find appropriate dimensions of the key
while calculate_tau(l, h) > 1 or calculate_sigma(l, h) > 1:
    if calculate_tau(l, h) > 1:
        l += 0.001  # Increase length incrementally
    if calculate_sigma(l, h) > 1:
        h += 0.001  # Increase height incrementally

# Print the final dimensions of the key
print(f"Dimensions of the key - Length (l): {l:.3f} m, Height (h): {h:.3f} m")

# Visualize key dimensions
# 2D diagram
plt.figure(figsize=(10, 6))
plt.plot([0, l], [0, 0], 'k-', linewidth=4)  # Bottom edge of the key
plt.plot([0, l], [h, h], 'k-', linewidth=4)  # Top edge of the key
plt.plot([0, 0], [0, h], 'k-', linewidth=2)  # Left edge of the key
plt.plot([l, l], [0, h], 'k-', linewidth=2)  # Right edge of the key
plt.xlim(-0.1, l + 0.1)
plt.ylim(-0.1, h + 0.1)
plt.xlabel('Length (m)')
plt.ylabel('Height (m)')
plt.title('2D Diagram of Flat Key')
plt.grid(True)
plt.savefig('flat_key_2d_diagram.png')  # Save the diagram
plt.show()

# 3D diagram
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot([0, l], [0, 0], [0, 0], color='black', linewidth=4)  # Bottom surface of the key
ax.plot([0, l], [h, h], [0, 0], color='black', linewidth=4)  # Top surface of the key
ax.plot([0, 0], [0, h], [0, 0], color='black', linewidth=2)  # Left edge of the key
ax.plot([l, l], [0, h], [0, 0], color='black', linewidth=2)  # Right edge of the key
ax.set_xlabel('Length (m)')
ax.set_ylabel('Height (m)')
ax.set_zlabel('Width (m)')
ax.set_title('3D Diagram of Flat Key')
plt.savefig('flat_key_3d_diagram.png')  # Save the diagram
plt.show()
# Out:
# Dimensions of the key - Length (l): 0.618 m, Height (h): 140175.403 m

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def plot_hydraulic_press():
    # Create data for the base plate of the press
    base_plate_x = np.array([0, 10, 10, 0, 0])
    base_plate_y = np.array([0, 0, 2, 2, 0])
    base_plate_z = np.array([0, 0, 0, 0, 0])

    # Create data for the moving part (piston and attached plate)
    piston_x = np.array([3, 7, 7, 3, 3])
    piston_y = np.array([0, 0, 0.5, 0.5, 0])
    piston_z = np.array([0, 0, 0, 0, 0])

    # Create a figure for 2D plot
    fig, ax = plt.subplots()
    ax.plot(base_plate_x, base_plate_y, 'b-', linewidth=2, label='Base Plate')
    ax.plot(piston_x, piston_y, 'r-', linewidth=2, label='Piston')

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Hydraulic Press 2D View')
    ax.legend()
    ax.grid(True)

    plt.show()

    # Create a 3D plot for perspective view
    fig_3d = plt.figure()
    ax3d = fig_3d.add_subplot(111, projection='3d')

    ax3d.plot(base_plate_x, base_plate_y, base_plate_z, 'b-', linewidth=2, label='Base Plate')
    ax3d.plot(piston_x, piston_y, piston_z, 'r-', linewidth=2, label='Piston')

    ax3d.set_xlabel('X')
    ax3d.set_ylabel('Y')
    ax3d.set_zlabel('Z')
    ax3d.set_title('Hydraulic Press 3D View')
    ax3d.legend()
    ax3d.grid(True)

    plt.show()

# Plot the hydraulic press simulation
plot_hydraulic_press()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def hydraulic_press_simulation(force, thickness):
    # Generate data for the squeezed material
    x = np.linspace(0, 1, 100)  # Sample points along x-axis
    y = np.linspace(0, thickness, 100)  # Sample points along y-axis
    X, Y = np.meshgrid(x, y)
    Z = force * (1 - Y/thickness)  # Simple linear compression model

    # Plot 2D image
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, Z, cmap='viridis')
    plt.colorbar(label='Pressure')
    plt.xlabel('Width')
    plt.ylabel('Thickness')
    plt.title('Hydraulic Press 2D Simulation')
    plt.grid(True)
    plt.gca().invert_yaxis()  # Invert y-axis for better visualization
    plt.savefig('hydraulic_press_2d.png')  # Save the image
    plt.show()

    # Plot 3D image
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('Width')
    ax.set_ylabel('Thickness')
    ax.set_zlabel('Pressure')
    ax.set_title('Hydraulic Press 3D Simulation')
    plt.savefig('hydraulic_press_3d.png')  # Save the image
    plt.show()

# Parameters for the hydraulic press
force_applied = 1000  # Arbitrary force applied (adjust as needed)
material_thickness = 10  # Thickness of the material being squeezed

# Run the simulation and plot images
hydraulic_press_simulation(force_applied, material_thickness)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def hydraulic_press_punching_simulation(punch_force, material_thickness, hole_radius):
    # Generate data for the punched material
    x = np.linspace(-1, 1, 100)  # Sample points along x-axis
    y = np.linspace(-1, 1, 100)  # Sample points along y-axis
    X, Y = np.meshgrid(x, y)

    # Calculate distance from the center (assumed punch location)
    distance_from_center = np.sqrt(X**2 + Y**2)

    # Determine the pressure distribution (simple model)
    pressure = np.zeros_like(distance_from_center)
    pressure[distance_from_center <= hole_radius] = punch_force

    # Plot 2D image
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, pressure, cmap='viridis')
    plt.colorbar(label='Pressure')
    plt.xlabel('Width')
    plt.ylabel('Height')
    plt.title('Hydraulic Press Punching 2D Simulation')
    plt.grid(True)
    plt.savefig('hydraulic_press_punching_2d.png')  # Save the image
    plt.show()

    # Plot 3D image
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, pressure, cmap='viridis')
    ax.set_xlabel('Width')
    ax.set_ylabel('Height')
    ax.set_zlabel('Pressure')
    ax.set_title('Hydraulic Press Punching 3D Simulation')
    plt.savefig('hydraulic_press_punching_3d.png')  # Save the image
    plt.show()

# Parameters for the hydraulic press punching simulation
punch_force_applied = 5000  # Force applied by the punch (adjust as needed)
material_thickness = 2  # Thickness of the material being punched
hole_radius = 0.5  # Radius of the punched hole

# Run the simulation and plot images
hydraulic_press_punching_simulation(punch_force_applied, material_thickness, hole_radius)

# %%
import numpy as np
import matplotlib.pyplot as plt

def gas_welding_simulation(heat_intensity, material_thickness):
    # Parameters for the welding torch and material
    torch_position = (0, 0)  # Position of the welding torch
    torch_radius = 0.2  # Radius of the welding torch
    material_length = 4  # Length of the material being welded

    # Generate data for the material
    x = np.linspace(-1, material_length, 200)
    y = np.linspace(-1, 1, 100)
    X, Y = np.meshgrid(x, y)

    # Calculate temperature distribution (simple model)
    temperature = heat_intensity * np.exp(-((X - torch_position[0])**2 + (Y - torch_position[1])**2) / torch_radius**2)

    # Plot 2D image
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, temperature, cmap='hot', levels=20)
    plt.colorbar(label='Temperature')
    plt.scatter([torch_position[0]], [torch_position[1]], color='blue', marker='o', label='Welding Torch')
    plt.xlabel('Length')
    plt.ylabel('Width')
    plt.title('Gas Welding Simulation')
    plt.legend()
    plt.grid(True)
    plt.savefig('gas_welding_simulation.png')  # Save the image
    plt.show()

# Parameters for the gas welding simulation
heat_intensity = 100  # Intensity of heat applied by the welding torch
material_thickness = 1  # Thickness of the material being welded

# Run the simulation and plot image
gas_welding_simulation(heat_intensity, material_thickness)

# %%
import numpy as np
import matplotlib.pyplot as plt

def draw_butt_joint():
    # Parameters for the butt joint diagram
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    gap_width = 0.1  # Gap between the plates

    # Draw the butt joint diagram
    plt.figure(figsize=(8, 4))
    plt.plot([0, plate_length], [0, 0], 'k-', linewidth=4)  # Bottom plate
    plt.plot([0, plate_length], [plate_thickness, plate_thickness], 'k-', linewidth=4)  # Top plate
    plt.plot([0, 0], [0, plate_thickness], 'k-', linewidth=2)  # Left edge of plates
    plt.plot([plate_length, plate_length], [0, plate_thickness], 'k-', linewidth=2)  # Right edge of plates
    plt.xlim(-0.5, plate_length + 0.5)
    plt.ylim(-0.1, plate_thickness + 0.1)
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('Butt Joint')
    plt.grid(True)
    plt.savefig('butt_joint_diagram.png')  # Save the diagram
    plt.show()

def simulate_butt_joint(heat_intensity):
    # Parameters for the simulation
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    gap_width = 0.1  # Gap between the plates

    # Generate data for the temperature distribution in the joint
    x = np.linspace(0, plate_length, 100)
    y = np.linspace(0, plate_thickness, 50)
    X, Y = np.meshgrid(x, y)
    temperature = heat_intensity * np.exp(-Y / (plate_thickness / 5))  # Simple temperature model

    # Plot the simulation
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, temperature, cmap='hot', levels=20)
    plt.colorbar(label='Temperature')
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('Butt Joint Welding Simulation')
    plt.grid(True)
    plt.savefig('butt_joint_simulation.png')  # Save the simulation
    plt.show()

def draw_lap_joint():
    # Parameters for the lap joint diagram
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    overlap_length = 2  # Length of overlap

    # Draw the lap joint diagram
    plt.figure(figsize=(8, 4))
    plt.plot([0, plate_length], [0, 0], 'k-', linewidth=4)  # Bottom plate
    plt.plot([0, overlap_length], [plate_thickness, plate_thickness], 'k-', linewidth=4)  # Top plate
    plt.plot([0, 0], [0, plate_thickness], 'k-', linewidth=2)  # Left edge of plates
    plt.plot([plate_length, plate_length], [0, plate_thickness], 'k-', linewidth=2)  # Right edge of plates
    plt.xlim(-0.5, plate_length + 0.5)
    plt.ylim(-0.1, plate_thickness + 0.1)
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('Lap Joint')
    plt.grid(True)
    plt.savefig('lap_joint_diagram.png')  # Save the diagram
    plt.show()

def simulate_lap_joint(heat_intensity):
    # Parameters for the simulation
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    overlap_length = 2  # Length of overlap

    # Generate data for the temperature distribution in the joint
    x = np.linspace(0, plate_length, 100)
    y = np.linspace(0, plate_thickness, 50)
    X, Y = np.meshgrid(x, y)
    temperature = heat_intensity * np.exp(-Y / (plate_thickness / 5))  # Simple temperature model

    # Plot the simulation
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, temperature, cmap='hot', levels=20)
    plt.colorbar(label='Temperature')
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('Lap Joint Welding Simulation')
    plt.grid(True)
    plt.savefig('lap_joint_simulation.png')  # Save the simulation
    plt.show()

def draw_t_joint():
    # Parameters for the T-joint diagram
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    overlap_length = 2  # Length of overlap

    # Draw the T-joint diagram
    plt.figure(figsize=(8, 4))
    plt.plot([0, plate_length], [0, 0], 'k-', linewidth=4)  # Bottom plate
    plt.plot([0, 0], [0, plate_thickness], 'k-', linewidth=2)  # Left edge of plates
    plt.plot([overlap_length, overlap_length], [0, plate_thickness], 'k-', linewidth=2)  # Right edge of overlap
    plt.plot([0, overlap_length], [plate_thickness, plate_thickness], 'k-', linewidth=4)  # Top plate
    plt.xlim(-0.5, plate_length + 0.5)
    plt.ylim(-0.1, plate_thickness + 0.1)
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('T-Joint')
    plt.grid(True)
    plt.savefig('t_joint_diagram.png')  # Save the diagram
    plt.show()

def simulate_t_joint(heat_intensity):
    # Parameters for the simulation
    plate_length = 5  # Length of the plates
    plate_thickness = 0.2  # Thickness of the plates
    overlap_length = 2  # Length of overlap

    # Generate data for the temperature distribution in the joint
    x = np.linspace(0, plate_length, 100)
    y = np.linspace(0, plate_thickness, 50)
    X, Y = np.meshgrid(x, y)
    temperature = heat_intensity * np.exp(-Y / (plate_thickness / 5))  # Simple temperature model

    # Plot the simulation
    plt.figure(figsize=(10, 6))
    plt.contourf(X, Y, temperature, cmap='hot', levels=20)
    plt.colorbar(label='Temperature')
    plt.xlabel('Length')
    plt.ylabel('Thickness')
    plt.title('T-Joint Welding Simulation')
    plt.grid(True)
    plt.savefig('t_joint_simulation.png')  # Save the simulation
    plt.show()

# Parameters for welding simulations
heat_intensity = 100  # Intensity of heat applied by the welding torch

# Draw and simulate each welding joint
draw_butt_joint()
simulate_butt_joint(heat_intensity)

draw_lap_joint()
simulate_lap_joint(heat_intensity)

draw_t_joint()
simulate_t_joint(heat_intensity)

# %%
# Constants and parameters
thermal_conductivity = 0.5  # W/m°C
wall_thickness = 0.2  # meters (200 mm)
area = 1  # m² (assuming 1 square meter area for simplicity)
inner_surface_temp = 2000  # °C
outer_surface_temp = 500  # °C

# Step 1: Calculate the temperature difference across the wall
delta_T = inner_surface_temp - outer_surface_temp

# Step 2: Calculate the heat flux (Q/A)
heat_flux = -thermal_conductivity * (delta_T / wall_thickness)

# Step 3: Calculate the heat loss per square meter
heat_loss_per_sqm = heat_flux * area

# Output the results
print(f"Heat loss per square meter of the wall: {heat_loss_per_sqm:.2f} W")
# Out:
# Heat loss per square meter of the wall: -3750.00 W

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
T_inner = 2000  # Temperature at inner surface (in °C)
T_outer = 500   # Temperature at outer surface (in °C)
k = 0.5         # Thermal conductivity of the brick (in W/m°C)
d = 0.2         # Wall thickness (in meters)

# Area of the wall (assuming 1 m² for simplicity)
A = 1  # in square meters

# Calculate heat transfer rate (Q) per square meter
Q = k * A * (T_inner - T_outer) / d

# Print the calculated heat transfer rate
print(f"Heat transfer rate per m² of the wall: {Q:.2f} Watts")

# Plotting temperature distribution across the wall thickness
num_points = 100
thickness = np.linspace(0, d, num_points)
temperature = T_inner - (T_inner - T_outer) * (thickness / d)

plt.figure(figsize=(10, 6))
plt.plot(temperature, thickness * 100, label='Temperature Distribution', color='blue', linewidth=2)
plt.xlabel('Temperature (°C)')
plt.ylabel('Thickness (cm)')
plt.title('Temperature Distribution Across Wall Thickness')
plt.grid(True)
plt.legend()
plt.savefig('temperature_distribution.png')  # Save the plot as an image file
plt.show()
# Out:
# Heat transfer rate per m² of the wall: 3750.00 Watts

# %%
import numpy as np

# Given data
power_hp = 125  # Power in horsepower
rpm = 250  # Rotational speed in rpm
shear_stress_psi = 19000  # Shear stress in psi
bearing_stress_psi = 37000  # Bearing stress in psi
shaft_diameter_in = 2  # Shaft diameter in inches

# Convert power to watts (1 hp = 745.7 watts)
power_w = power_hp * 745.7

# Convert rotational speed to radians per second
omega = rpm * 2 * np.pi / 60

# Calculate torque (T = P / omega)
torque_in_lbf = power_w / omega  # Torque in inch-pounds-force

# Calculate key dimensions
# For shear: T = τ * (w * h / 2) * r
# For bearing: T = σ * (w * h) * r
# τ = shear stress, σ = bearing stress, w = width, h = height, r = radius

# Assuming square key (w = h)
radius_in = shaft_diameter_in / 2

# Calculate width (w) and height (h) based on shear stress
width_height_in = np.sqrt(2 * torque_in_lbf / (shear_stress_psi * radius_in))

# Check bearing stress
bearing_check = torque_in_lbf / (bearing_stress_psi * width_height_in * radius_in)
if bearing_check <= width_height_in:
    print("Key dimensions based on shear stress are adequate.")
else:
    print("Key dimensions need to be adjusted based on bearing stress.")

# Print results
print(f"Calculated key width and height: {width_height_in:.4f} inches")

# Plotting the key and shaft for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Shaft dimensions
shaft_length_in = 6  # Length of the shaft in inches

# Create a figure and axis
fig, ax = plt.subplots()

# Add a rectangle for the shaft
shaft = patches.Rectangle((0, -shaft_diameter_in / 2), shaft_length_in, shaft_diameter_in, linewidth=1, edgecolor='black', facecolor='grey')
ax.add_patch(shaft)

# Add a rectangle for the key
key = patches.Rectangle((shaft_length_in / 2 - width_height_in / 2, -width_height_in / 2), width_height_in, width_height_in, linewidth=1, edgecolor='black', facecolor='yellow')
ax.add_patch(key)

# Set the axis limits
ax.set_xlim(-1, shaft_length_in + 1)
ax.set_ylim(-shaft_diameter_in, shaft_diameter_in)
ax.set_aspect('equal')

# Add labels and title
plt.xlabel('Length (inches)')
plt.ylabel('Diameter (inches)')
plt.title('Shaft and Key Visualization')
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Key dimensions based on shear stress are adequate.
# Calculated key width and height: 0.6122 inches

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.animation as animation

# Given data
shaft_diameter_in = 2  # Shaft diameter in inches
shaft_radius_in = shaft_diameter_in / 2
key_width_in = 0.39  # Calculated key width and height (in inches)
key_height_in = 0.39  # Calculated key width and height (in inches)
shaft_length_in = 6  # Length of the shaft (in inches)

# Create figure and axis
fig, ax = plt.subplots()

# Draw the shaft
shaft = patches.Rectangle((0, -shaft_radius_in), shaft_length_in, shaft_diameter_in, linewidth=1, edgecolor='black', facecolor='grey')
ax.add_patch(shaft)

# Draw the key
key = patches.Rectangle((shaft_length_in / 2 - key_width_in / 2, -key_height_in / 2), key_width_in, key_height_in, linewidth=1, edgecolor='black', facecolor='yellow')
ax.add_patch(key)

# Function to animate the rotation
def animate(i):
    key_center_x = shaft_length_in / 2
    key_center_y = 0
    key_angle = np.deg2rad(i)  # Convert degrees to radians

    key.set_xy([key_center_x + key_width_in/2 * np.sin(key_angle) - key_width_in / 2,
                key_center_y + key_height_in/2 * np.cos(key_angle) - key_height_in / 2])

    return key,

# Create animation
ani = animation.FuncAnimation(fig, animate, frames=np.arange(0, 360, 5), interval=50, blit=True)

# Set axis limits and labels
ax.set_xlim(-1, shaft_length_in + 1)
ax.set_ylim(-shaft_radius_in * 2, shaft_radius_in * 2)
ax.set_aspect('equal')
plt.xlabel('Length (inches)')
plt.ylabel('Diameter (inches)')
plt.title('Shaft and Key Torque Transmission Simulation')
plt.grid(True)

# Save the animation
ani.save('shaft_key_simulation.gif', writer='imagemagick')

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Plot the synthetic data
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Synthetic Data")
plt.show()

# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.1
iterations = 1000

# Store the values of m and b for plotting
m_history = []
b_history = []
loss_history = []

# Define loss function and gradient calculation
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

def compute_gradients(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    dm = -(2/n) * np.sum(X * (y - predictions))
    db = -(2/n) * np.sum(y - predictions)
    return dm, db

# Gradient Descent
for i in range(iterations):
    m_history.append(m[0])
    b_history.append(b[0])
    loss = compute_loss(X, y, m, b)
    loss_history.append(loss)

    dm, db = compute_gradients(X, y, m, b)

    m -= learning_rate * dm
    b -= learning_rate * db

    if i % 100 == 0:
        print(f"Iteration {i}: m = {m[0]}, b = {b[0]}, loss = {loss}")

# Plot loss over iterations
plt.plot(loss_history)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Over Iterations")
plt.show()

# Plot the fitted line
plt.scatter(X, y, label="Data points")
plt.plot(X, m * X + b, color="red", label="Fitted line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit")
plt.legend()
plt.show()
# Out:
# Iteration 0: m = 1.2132381248493407, b = 2.5243827860708423, loss = 32.138586076383035
# Iteration 100: m = 2.7750759859121157, b = 4.209475653611081, loss = 0.8065947869466693
# Iteration 200: m = 2.7702704270896166, b = 4.214918297616194, loss = 0.8065845742043011
# Iteration 300: m = 2.770118355964282, b = 4.215090529198247, loss = 0.8065845639773048
# Iteration 400: m = 2.770113543698317, b = 4.215095979438578, loss = 0.8065845639670636
# Iteration 500: m = 2.770113391414945, b = 4.2150961519105445, loss = 0.8065845639670534
# Iteration 600: m = 2.7701133865959626, b = 4.215096157368392, loss = 0.8065845639670534
# Iteration 700: m = 2.770113386443468, b = 4.215096157541103, loss = 0.8065845639670534
# Iteration 800: m = 2.770113386438642, b = 4.2150961575465695, loss = 0.8065845639670532
# Iteration 900: m = 2.7701133864384917, b = 4.215096157546739, loss = 0.806584563967053

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.01
iterations = 1000

# Store the values of m and b for plotting
m_history = []
b_history = []
loss_history = []

# Define loss function and gradient calculation
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

def compute_gradients(X, y, m, b):
    predictions = m * X + b
    dm = -2 * X * (y - predictions)
    db = -2 * (y - predictions)
    return dm, db

# Stochastic Gradient Descent
for i in range(iterations):
    for j in range(len(X)):
        m_history.append(m[0])
        b_history.append(b[0])
        loss = compute_loss(X, y, m, b)
        loss_history.append(loss)

        dm, db = compute_gradients(X[j:j+1], y[j:j+1], m, b)

        m -= learning_rate * dm
        b -= learning_rate * db

    if i % 100 == 0:
        print(f"Iteration {i}: m = {m[0]}, b = {b[0]}, loss = {loss}")

# Plot loss over iterations
plt.plot(loss_history)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Over Iterations (SGD)")
plt.show()

# Plot the fitted line
plt.scatter(X, y, label="Data points")
plt.plot(X, m * X + b, color="red", label="Fitted line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit (SGD)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0b1b31616ddd> in <cell line: 36>()
#      43         dm, db = compute_gradients(X[j:j+1], y[j:j+1], m, b)
#      44
# ---> 45         m -= learning_rate * dm
#      46         b -= learning_rate * db
#      47
#
# ValueError: non-broadcastable output operand with shape (1,) doesn't match the broadcast shape (1,1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.01
iterations = 1000

# Store the values of m and b for plotting
m_history = []
b_history = []
loss_history = []

# Define loss function and gradient calculation
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

def compute_gradients(X, y, m, b):
    predictions = m * X + b
    dm = -2 * np.mean(X * (y - predictions)) # Calculate the mean of the gradient to get a scalar value
    db = -2 * np.mean(y - predictions) # Calculate the mean of the gradient to get a scalar value
    return dm, db

# Stochastic Gradient Descent
for i in range(iterations):
    for j in range(len(X)):
        m_history.append(m[0])
        b_history.append(b[0])
        loss = compute_loss(X, y, m, b)
        loss_history.append(loss)

        dm, db = compute_gradients(X[j:j+1], y[j:j+1], m, b)

        m -= learning_rate * dm # Now m and dm have compatible shapes
        b -= learning_rate * db # Now b and db have compatible shapes

    if i % 100 == 0:
        print(f"Iteration {i}: m = {m[0]}, b = {b[0]}, loss = {loss}")

# Plot loss over iterations
plt.plot(loss_history)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Over Iterations (SGD)")
plt.show()

# Plot the fitted line
plt.scatter(X, y, label="Data points")
plt.plot(X, m * X + b, color="red", label="Fitted line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit (SGD)")
plt.legend()
plt.show()
# Out:
# Iteration 0: m = 2.914884956199309, b = 4.095278580075658, loss = 0.8136025086253292
# Iteration 100: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 200: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 300: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 400: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 500: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 600: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 700: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 800: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579
# Iteration 900: m = 2.8474106016049006, b = 4.255609543824685, loss = 0.8182086828566579

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate, number of iterations, and mini-batch size
learning_rate = 0.01
iterations = 1000
batch_size = 20

# Store the values of m and b for plotting
m_history = []
b_history = []
loss_history = []

# Define loss function and gradient calculation
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

def compute_gradients(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    dm = -(2/n) * np.sum(X * (y - predictions))
    db = -(2/n) * np.sum(y - predictions)
    return dm, db

# Mini-Batch Gradient Descent
for i in range(iterations):
    indices = np.random.permutation(len(X))
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    for j in range(0, len(X), batch_size):
        X_batch = X_shuffled[j:j+batch_size]
        y_batch = y_shuffled[j:j+batch_size]

        m_history.append(m[0])
        b_history.append(b[0])
        loss = compute_loss(X, y, m, b)
        loss_history.append(loss)

        dm, db = compute_gradients(X_batch, y_batch, m, b)

        m -= learning_rate * dm
        b -= learning_rate * db

    if i % 100 == 0:
        print(f"Iteration {i}: m = {m[0]}, b = {b[0]}, loss = {loss}")

# Plot loss over iterations
plt.plot(loss_history)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss Over Iterations (Mini-Batch GD)")
plt.show()

# Plot the fitted line
plt.scatter(X, y, label="Data points")
plt.plot(X, m * X + b, color="red", label="Fitted line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit (Mini-Batch GD)")
plt.legend()
plt.show()
# Out:
# Iteration 0: m = 0.5649338005945209, b = 1.9454949950694553, loss = 22.9249334077371
# Iteration 100: m = 2.7984702472424985, b = 4.18107373327401, loss = 0.8069347440206387
# Iteration 200: m = 2.7768226431180376, b = 4.210167909524481, loss = 0.8066083436576004
# Iteration 300: m = 2.7708105675291756, b = 4.213925271244125, loss = 0.8065889063261337
# Iteration 400: m = 2.768853339662547, b = 4.213759422902229, loss = 0.8065851172095176
# Iteration 500: m = 2.7706454652150274, b = 4.215487464483393, loss = 0.806589752016906
# Iteration 600: m = 2.7708545557084365, b = 4.216038449416185, loss = 0.806614677295141
# Iteration 700: m = 2.76979811919366, b = 4.214527559532623, loss = 0.8066119475912272
# Iteration 800: m = 2.768796646064163, b = 4.213794204773051, loss = 0.8067448930718681
# Iteration 900: m = 2.768801080612566, b = 4.214093789995102, loss = 0.8066290398606382

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Define loss function and gradient calculation
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

def compute_gradients(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    dm = -(2/n) * np.sum(X * (y - predictions))
    db = -(2/n) * np.sum(y - predictions)
    return dm, db

# %%
# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.1
iterations = 1000

# Store the values of m, b, and loss for plotting
m_history = []
b_history = []
loss_history = []

# Batch Gradient Descent
for i in range(iterations):
    m_history.append(m[0])
    b_history.append(b[0])
    loss = compute_loss(X, y, m, b)
    loss_history.append(loss)

    dm, db = compute_gradients(X, y, m, b)

    m -= learning_rate * dm
    b -= learning_rate * db

# 3D Plot for Batch Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history, b_history, loss_history, label='Batch GD', color='r')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Batch Gradient Descent')
plt.show()

# %%
# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.01
iterations = 1000

# Store the values of m, b, and loss for plotting
m_history = []
b_history = []
loss_history = []

# Stochastic Gradient Descent
for i in range(iterations):
    for j in range(len(X)):
        m_history.append(m[0])
        b_history.append(b[0])
        loss = compute_loss(X, y, m, b)
        loss_history.append(loss)

        dm, db = compute_gradients(X[j:j+1], y[j:j+1], m, b)

        m -= learning_rate * dm
        b -= learning_rate * db

# 3D Plot for Stochastic Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history, b_history, loss_history, label='SGD', color='b')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Stochastic Gradient Descent')
plt.show()

# %%
# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate, number of iterations, and mini-batch size
learning_rate = 0.01
iterations = 1000
batch_size = 20

# Store the values of m, b, and loss for plotting
m_history = []
b_history = []
loss_history = []

# Mini-Batch Gradient Descent
for i in range(iterations):
    indices = np.random.permutation(len(X))
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    for j in range(0, len(X), batch_size):
        X_batch = X_shuffled[j:j+batch_size]
        y_batch = y_shuffled[j:j+batch_size]

        m_history.append(m[0])
        b_history.append(b[0])
        loss = compute_loss(X, y, m, b)
        loss_history.append(loss)

        dm, db = compute_gradients(X_batch, y_batch, m, b)

        m -= learning_rate * dm
        b -= learning_rate * db

# 3D Plot for Mini-Batch Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history, b_history, loss_history, label='Mini-Batch GD', color='g')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Mini-Batch Gradient Descent')
plt.show()

# %% [markdown]
# Explanation
# Batch Gradient Descent: The parameters are updated using the entire dataset, and the 3D plot shows a smooth path towards the minimum loss.
# Stochastic Gradient Descent (SGD): The parameters are updated for each training example, and the 3D plot shows a more erratic path due to the high variance in the updates.
# Mini-Batch Gradient Descent: The parameters are updated using small batches of data, providing a balance between the smooth path of Batch Gradient Descent and the high variance of SGD.
# By plotting the evolution of the parameters
# 𝑚
# m and
# 𝑏
# b along with the loss in 3D, we can visualize how each gradient descent method navigates the loss surface to find the optimal parameters

# %%
import numpy as np

# Generate synthetic data
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
# Define loss function
def compute_loss(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    loss = (1/n) * np.sum((y - predictions) ** 2)
    return loss

# Define gradients
def compute_gradients(X, y, m, b):
    n = len(y)
    predictions = m * X + b
    dm = -(2/n) * np.sum(X * (y - predictions))
    db = -(2/n) * np.sum(y - predictions)
    return dm, db

# %%
# Initialize parameters
m = np.random.randn(1)
b = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.1
iterations = 1000

# Store the values of m, b, and loss for plotting
m_history = []
b_history = []
loss_history = []

# Batch Gradient Descent
for i in range(iterations):
    m_history.append(m[0])
    b_history.append(b[0])
    loss = compute_loss(X, y, m, b)
    loss_history.append(loss)

    dm, db = compute_gradients(X, y, m, b)

    m -= learning_rate * dm
    b -= learning_rate * db

# %%
# Initialize parameters
m_sgd = np.random.randn(1)
b_sgd = np.random.randn(1)

# Set learning rate and number of iterations
learning_rate = 0.01
iterations = 1000

# Store the values of m, b, and loss for plotting
m_history_sgd = []
b_history_sgd = []
loss_history_sgd = []

# Stochastic Gradient Descent
for i in range(iterations):
    for j in range(len(X)):
        m_history_sgd.append(m_sgd[0])
        b_history_sgd.append(b_sgd[0])
        loss = compute_loss(X, y, m_sgd, b_sgd)
        loss_history_sgd.append(loss)

        dm, db = compute_gradients(X[j:j+1], y[j:j+1], m_sgd, b_sgd)

        m_sgd -= learning_rate * dm
        b_sgd -= learning_rate * db

# %%
# Initialize parameters
m_mb = np.random.randn(1)
b_mb = np.random.randn(1)

# Set learning rate, number of iterations, and mini-batch size
learning_rate = 0.01
iterations = 1000
batch_size = 20

# Store the values of m, b, and loss for plotting
m_history_mb = []
b_history_mb = []
loss_history_mb = []

# Mini-Batch Gradient Descent
for i in range(iterations):
    indices = np.random.permutation(len(X))
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    for j in range(0, len(X), batch_size):
        X_batch = X_shuffled[j:j+batch_size]
        y_batch = y_shuffled[j:j+batch_size]

        m_history_mb.append(m_mb[0])
        b_history_mb.append(b_mb[0])
        loss = compute_loss(X, y, m_mb, b_mb)
        loss_history_mb.append(loss)

        dm, db = compute_gradients(X_batch, y_batch, m_mb, b_mb)

        m_mb -= learning_rate * dm
        b_mb -= learning_rate * db

# %%
# Initialize parameters
m_mb = np.random.randn(1)
b_mb = np.random.randn(1)

# Set learning rate, number of iterations, and mini-batch size
learning_rate = 0.01
iterations = 1000
batch_size = 20

# Store the values of m, b, and loss for plotting
m_history_mb = []
b_history_mb = []
loss_history_mb = []

# Mini-Batch Gradient Descent
for i in range(iterations):
    indices = np.random.permutation(len(X))
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    for j in range(0, len(X), batch_size):
        X_batch = X_shuffled[j:j+batch_size]
        y_batch = y_shuffled[j:j+batch_size]

        m_history_mb.append(m_mb[0])
        b_history_mb.append(b_mb[0])
        loss = compute_loss(X, y, m_mb, b_mb)
        loss_history_mb.append(loss)

        dm, db = compute_gradients(X_batch, y_batch, m_mb, b_mb)

        m_mb -= learning_rate * dm
        b_mb -= learning_rate * db

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 3D Plot for Batch Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history, b_history, loss_history, label='Batch GD', color='r')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Batch Gradient Descent')
plt.show()

# 3D Plot for Stochastic Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history_sgd, b_history_sgd, loss_history_sgd, label='SGD', color='b')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Stochastic Gradient Descent')
plt.show()

# 3D Plot for Mini-Batch Gradient Descent
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(m_history_mb, b_history_mb, loss_history_mb, label='Mini-Batch GD', color='g')
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
ax.set_title('Mini-Batch Gradient Descent')
plt.show()
